# %%
import os 
import glob 
import pandas as pd

# %%
path = './data/ccm_rul_dataset.csv'

# %%
df = pd.read_csv(path)

df.head()
# Out:
#          date  workpiece_weight, tonn steel_type doc_requirement  cast_in_row  \
# 0  2020-01-05                   144.9     Arm240  DOC 34028-2016            4
# 1  2020-01-05                   165.9      St3sp        Contract           10
# 2  2020-01-05                   168.0     Arm240  DOC 34028-2016            5
# 3  2020-01-05                   170.1      St3sp        Contract            7
# 4  2020-01-05                   163.8      St3sp        Contract           12
#
#   workpiece_slice_geometry alloy_type  steel_weight_theoretical, tonn  \
# 0                  150x150       open                           145.3
# 1                  150x150       open                           166.3
# 2                  150x150       open                           168.4
# 3                  150x150       open                           170.5
# 4                  150x150       open                           164.2
#
#    slag_weight_close_grab1, tonn  metal_residue_grab1, tonn  ...   Al, %  \
# 0                            1.8                        0.4  ...  0.0022
# 1                            1.8                        0.4  ...  0.0028
# 2                            1.8                        0.4  ...  0.0031
# 3                            1.8                        0.4  ...  0.0034
# 4                            1.8                        0.4  ...  0.0032
#
#     Ca, %    N, %  Pb, %  Mg, %  Zn, %    sleeve  num_crystallizer  \
# 0  0.0008  0.0085    0.0    0.0    0.0  30012261                22
# 1  0.0004  0.0049    0.0    0.0    0.0  30013346                 2
# 2  0.0011  0.0068    0.0    0.0    0.0  30012261                22
# 3  0.0005  0.0051    0.0    0.0    0.0  30012261                22
# 4  0.0004  0.0038    0.0    0.0    0.0  30012261                22
#
#    num_stream     RUL
# 0           4   384.0
# 1           1  1037.0
# 2           4   355.0
# 3           4   300.0
# 4           4   164.0
#
# [5 rows x 57 columns]

# %% [markdown]
# data 컬럼
#
# - 'date'
#     - 데이터 기록 시간
# - 'workpiece_weight, tonn',
#     -
# - 'steel_type',
# - 'doc_requirement',
# - 'cast_in_row',
# - 'workpiece_slice_geometry',
# - 'alloy_type',
# - 'steel_weight_theoretical, tonn',
# - 'slag_weight_close_grab1, tonn',
# - 'metal_residue_grab1, tonn',
# - 'steel_weight, tonn',
# - 'residuals_grab2, tonn',
# - 'technical_trim, tonn',
# - 'grab1_num',
# - 'steel_temperature_grab1, Celsius deg.',
# - 'grab2_num',
# - 'resistance, tonn',
# - 'swing_frequency, amount/minute',
# - 'crystallizer_movement, mm',
# - 'alloy_speed, meter/minute',
# - 'water_consumption, liter/minute',
# - 'water_temperature_delta, Celsius deg.',
# - 'water_consumption_secondary_cooling_zone_num1, liter/minute',
# - 'water_consumption_secondary_cooling_zone_num2, liter/minute',
# - 'water_consumption_secondary_cooling_zone_num3, liter/minute',
# - 'kind',
# - 'quantity, tonn',
# - 'time_temperature_measurement1',
# - 'temperature_measurement1, Celsius deg.',
# - 'time_temperature_measurement2',
# - 'temperature_measurement2, Celsius deg.',
# - 'sample_time_continuous_caster', 'Ce, %', 'C, %', 'Si, %', 'Mn,%',
# - 'S, %',
# - 'P, %',
# - 'Cr, %',
# - 'Ni, %',
# - 'Cu, %',
# - 'As, %',
# - 'Mo, %',
# - 'Nb, %',
# - 'Sn, %',
# - 'Ti, %',
# - 'V, %',
# - 'Al, %',
# - 'Ca, %',
# - 'N, %',
# - 'Pb, %',
# - 'Mg, %',
# - 'Zn, %',
# - 'sleeve',
# - 'num_crystallizer',
# - 'num_stream',
# - 'RUL'
#     - remaining useful lifetime (RUL), 이 열은 "resistance, tonn" 열에서 각 sleeve에 대해 가장 높은 저항(차단 순간) 전류 값에서 num_crystallizer 및 num_stream을 뺍니다. 즉, 이 열은 각 슬리브의 현재 저항 값이 최대 저항 값에서 얼마나 떨어져 있는지를 나타내는 값을 보여줍니다. 이러한 계산은 각 슬리브의 남은 내구성 또는 수명을 추정하는 데 도움이 될 수 있습니다.
